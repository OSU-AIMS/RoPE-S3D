# %% [markdown]
# <a href="https://colab.research.google.com/github/jgraving/deepposekit/blob/master/examples/step1_create_annotation_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DeepPoseKit Step 1 - Create an annotation set
#
# This is step 1 of the example notebooks for using DeepPoseKit. This notebook shows you how to load and sample images from a video, define a keypoint skeleton, and save the data to a file for labelling with keypoints.
#
#
# **NOTE**: If you run into problems, you can help us improve DeepPoseKit by [opening an issue](https://github.com/jgraving/deepposekit/issues/new) or [submitting a pull request](https://help.github.com/en/articles/creating-a-pull-request-from-a-fork)

# %% [markdown]
# If you haven't already installed DeepPoseKit you can run the next cell

# %%
import sys
# !{sys.executable} -m pip install -U deepposekit
# Out:
# Requirement already up-to-date: deepposekit in c:\users\exley\anaconda3\lib\site-packages (0.3.9)
# Requirement already satisfied, skipping upgrade: h5py in c:\users\exley\anaconda3\lib\site-packages (from deepposekit) (2.10.0)
# Requirement already satisfied, skipping upgrade: pandas in c:\users\exley\anaconda3\lib\site-packages (from deepposekit) (1.0.5)
# Requirement already satisfied, skipping upgrade: imgaug>=0.2.9 in c:\users\exley\anaconda3\lib\site-packages (from deepposekit) (0.4.0)
# Requirement already satisfied, skipping upgrade: matplotlib in c:\users\exley\anaconda3\lib\site-packages (from deepposekit) (3.2.2)
# Requirement already satisfied, skipping upgrade: opencv-python in c:\users\exley\anaconda3\lib\site-packages (from deepposekit) (4.4.0.46)
# Requirement already satisfied, skipping upgrade: numpy in c:\users\exley\anaconda3\lib\site-packages (from deepposekit) (1.18.5)
# Requirement already satisfied, skipping upgrade: pyyaml in c:\users\exley\anaconda3\lib\site-packages (from deepposekit) (5.3.1)
# Requirement already satisfied, skipping upgrade: six in c:\users\exley\anaconda3\lib\site-packages (from h5py->deepposekit) (1.15.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\exley\anaconda3\lib\site-packages (from pandas->deepposekit) (2020.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in c:\users\exley\anaconda3\lib\site-packages (from pandas->deepposekit) (2.8.1)
# Requirement already satisfied, skipping upgrade: Pillow in c:\users\exley\anaconda3\lib\site-packages (from imgaug>=0.2.9->deepposekit) (7.2.0)
# Requirement already satisfied, skipping upgrade: imageio in c:\users\exley\anaconda3\lib\site-packages (from imgaug>=0.2.9->deepposekit) (2.9.0)
# Requirement already satisfied, skipping upgrade: scipy in c:\users\exley\anaconda3\lib\site-packages (from imgaug>=0.2.9->deepposekit) (1.5.0)
# Requirement already satisfied, skipping upgrade: scikit-image>=0.14.2 in c:\users\exley\anaconda3\lib\site-packages (from imgaug>=0.2.9->deepposekit) (0.16.2)
# Requirement already satisfied, skipping upgrade: Shapely in c:\users\exley\anaconda3\lib\site-packages (from imgaug>=0.2.9->deepposekit) (1.7.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in c:\users\exley\anaconda3\lib\site-packages (from matplotlib->deepposekit) (2.4.7)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\exley\anaconda3\lib\site-packages (from matplotlib->deepposekit) (1.2.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\exley\anaconda3\lib\site-packages (from matplotlib->deepposekit) (0.10.0)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in c:\users\exley\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug>=0.2.9->deepposekit) (2.4)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in c:\users\exley\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug>=0.2.9->deepposekit) (1.1.1)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in c:\users\exley\anaconda3\lib\site-packages (from networkx>=2.0->scikit-image>=0.14.2->imgaug>=0.2.9->deepposekit) (4.4.2)
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the 'C:\Users\exley\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import cv2
import h5py
import matplotlib.pyplot as plt
from deepposekit.io import VideoReader, DataGenerator, initialize_dataset
from deepposekit.annotate import KMeansSampler
import tqdm
import glob
import pandas as pd

from os.path import expanduser

try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

HOME = expanduser("~") if not IN_COLAB else '.'

# %% [markdown]
# Use the next cell to download the example data into your home directory

# %%
# !git clone https://github.com/jgraving/deepposekit-data {HOME + '/deepposekit-data'}

# %% [markdown]
# # A note on image resolutions
#
# Currently DeepPoseKit only supports image resolutions that can be repeatedly divided by 2. For example, all of these values are valid image resolutions for either height or width:

# %%
exp = np.arange(1,12)
exp = 2**exp

print(1*exp)
print(3*exp)
print(5*exp)
print(7*exp)
print(11*exp)
# Out:
# [   2    4    8   16   32   64  128  256  512 1024 2048]
# [   6   12   24   48   96  192  384  768 1536 3072 6144]
# [   10    20    40    80   160   320   640  1280  2560  5120 10240]
# [   14    28    56   112   224   448   896  1792  3584  7168 14336]
# [   22    44    88   176   352   704  1408  2816  5632 11264 22528]

# %% [markdown]
# Images that do not match these resolutions must be manually resized, cropped, or padded. We are working to add automated image size adjustments.

# %% [markdown]
# # Open a video
# The `VideoReader` class allows you to load in single video frames or batches of frames from nearly any video format.

# %%
videos = glob.glob(HOME + '/deepposekit-data/datasets/fly/*.avi')
videos
# Out:
# ['/Users/jake/deepposekit-data/datasets/fly/video.avi']

# %%
reader = VideoReader(HOME + '/deepposekit-data/datasets/fly/video.avi', gray=True)
frame = reader[0] # read a frame
reader.close()
frame.shape
# Out:
# (1, 192, 192, 1)

# %%
plt.figure(figsize=(5,5))
plt.imshow(frame[0,...,0])
plt.show()

# %% [markdown]
# # Sample video frames
# This loads batches of 100 frames from the video, and then randomly samples frames from the batches to hold them in memory. You can use any method for sampling frames.

# %%
reader = VideoReader(HOME + '/deepposekit-data/datasets/fly/video.avi', batch_size=100, gray=True)

randomly_sampled_frames = []
for idx in tqdm.tqdm(range(len(reader)-1)):
    batch = reader[idx]
    random_sample = batch[np.random.choice(batch.shape[0], 10, replace=False)]
    randomly_sampled_frames.append(random_sample)
reader.close()

randomly_sampled_frames = np.concatenate(randomly_sampled_frames)
randomly_sampled_frames.shape
# Out:
# 100%|██████████| 337/337 [00:04<00:00, 72.05it/s]
# (3370, 192, 192, 1)

# %% [markdown]
# # Apply k-means to reduce correlation
#
# This applies the k-means algorithm to the images using `KMeansSampler` to even out sampling across the distribution of images and reduce correlation within the annotation set.

# %%
kmeans = KMeansSampler(n_clusters=10, max_iter=1000, n_init=10, batch_size=100, verbose=True)
kmeans.fit(randomly_sampled_frames)
# Out:
# Init 1/10 with method: k-means++
# Inertia for init 1/10: 2804070345.096643
# Init 2/10 with method: k-means++
# Inertia for init 2/10: 2725729921.996540
# Init 3/10 with method: k-means++
# Inertia for init 3/10: 2625251923.569137
# Init 4/10 with method: k-means++
# Inertia for init 4/10: 2870407073.767202
# Init 5/10 with method: k-means++
# Inertia for init 5/10: 2837006655.084984
# Init 6/10 with method: k-means++
# Inertia for init 6/10: 2633940551.680360
# Init 7/10 with method: k-means++
# Inertia for init 7/10: 2825756611.526105
# Init 8/10 with method: k-means++
# Inertia for init 8/10: 2868547863.781259
# Init 9/10 with method: k-means++
# Inertia for init 9/10: 2727648136.498062
# Init 10/10 with method: k-means++
# Inertia for init 10/10: 2779370932.460431
# Minibatch iteration 1/34000: mean batch inertia: 9446134.691141, ewa inertia: 9446134.691141
# Minibatch iteration 2/34000: mean batch inertia: 8548716.913970, ewa inertia: 9392891.275112
# Minibatch iteration 3/34000: mean batch inertia: 8698920.946001, ewa inertia: 9351718.309872
# Minibatch iteration 4/34000: mean batch inertia: 8839115.132218, ewa inertia: 9321305.780792
# Minibatch iteration 5/34000: mean batch inertia: 8975795.615332, ewa inertia: 9300806.809243
# Minibatch iteration 6/34000: mean batch inertia: 8287916.018466, ewa inertia: 9240712.428301
# Minibatch iteration 7/34000: mean batch inertia: 8454820.909619, ewa inertia: 9194085.817878
# Minibatch iteration 8/34000: mean batch inertia: 8610653.191426, ewa inertia: 9159471.007646
# Minibatch iteration 9/34000: mean batch inertia: 8918505.584093, ewa inertia: 9145174.631286
# Minibatch iteration 10/34000: mean batch inertia: 8458898.781267, ewa inertia: 9104458.176227
# Minibatch iteration 11/34000: mean batch inertia: 8663463.081643, ewa inertia: 9078294.124338
# Minibatch iteration 12/34000: mean batch inertia: 8519079.159094, ewa inertia: 9045116.137673
# Minibatch iteration 13/34000: mean batch inertia: 8628622.684864, ewa inertia: 9020405.757797
# Minibatch iteration 14/34000: mean batch inertia: 9035390.347842, ewa inertia: 9021294.787168
# Minibatch iteration 15/34000: mean batch inertia: 8968636.899495, ewa inertia: 9018170.617030
# Minibatch iteration 16/34000: mean batch inertia: 8227765.998665, ewa inertia: 8971276.246317
# Minibatch iteration 17/34000: mean batch inertia: 8228096.986494, ewa inertia: 8927183.736093
# Minibatch iteration 18/34000: mean batch inertia: 8859301.978519, ewa inertia: 8923156.340212
# Minibatch iteration 19/34000: mean batch inertia: 8716314.440904, ewa inertia: 8910884.498070
# Minibatch iteration 20/34000: mean batch inertia: 8799757.402493, ewa inertia: 8904291.374630
# Minibatch iteration 21/34000: mean batch inertia: 7573371.133273, ewa inertia: 8825328.441295
# Minibatch iteration 22/34000: mean batch inertia: 9331853.449099, ewa inertia: 8855380.355137
# Minibatch iteration 23/34000: mean batch inertia: 8321373.668546, ewa inertia: 8823697.964951
# Minibatch iteration 24/34000: mean batch inertia: 8654999.264587, ewa inertia: 8813689.142621
# Minibatch iteration 25/34000: mean batch inertia: 8165541.512132, ewa inertia: 8775234.818653
# Minibatch iteration 26/34000: mean batch inertia: 8524920.618467, ewa inertia: 8760383.783341
# Minibatch iteration 27/34000: mean batch inertia: 8805023.929166, ewa inertia: 8763032.264256
# Minibatch iteration 28/34000: mean batch inertia: 9219912.177978, ewa inertia: 8790138.755726
# Minibatch iteration 29/34000: mean batch inertia: 9804724.285924, ewa inertia: 8850333.684838
# Minibatch iteration 30/34000: mean batch inertia: 9622403.855746, ewa inertia: 8896140.280561
# Minibatch iteration 31/34000: mean batch inertia: 8781735.584408, ewa inertia: 8889352.698470
# Minibatch iteration 32/34000: mean batch inertia: 8092292.364053, ewa inertia: 8842063.446947
# Minibatch iteration 33/34000: mean batch inertia: 8109901.673552, ewa inertia: 8798624.599519
# Minibatch iteration 34/34000: mean batch inertia: 9510829.558848, ewa inertia: 8840879.417634
# Minibatch iteration 35/34000: mean batch inertia: 8583661.411446, ewa inertia: 8825618.782441
# Minibatch iteration 36/34000: mean batch inertia: 8308794.743544, ewa inertia: 8794955.831453
# Converged (lack of improvement in inertia) at iteration 36/34000
# Computing label assignment and total inertia
# KMeansSampler(max_iter=1000, n_init=10, verbose=True)

# %%
kmeans.plot_centers(n_rows=2)
plt.show()

# %%
kmeans_sampled_frames, kmeans_cluster_labels = kmeans.sample_data(randomly_sampled_frames, n_samples_per_label=10)
kmeans_sampled_frames.shape
# Out:
# Computing label assignment and total inertia
# Computing label assignment and total inertia
# (100, 192, 192, 1)

# %% [markdown]
# # Define a keypoints skeleton file
# You must create a .xlsx or .csv file with keypoint names, parent relationships, and swapping relationships for bilaterally symmetric parts (only relevant if using flipping augmentations). If you leave out the `parent` and `swap` columns, then these will simply not be used for annotating data and training the model.
#
# See example skeleton.csv files for more details

# %%
skeleton = pd.read_csv(HOME + '/deepposekit-data/datasets/fly/skeleton.csv')
skeleton
# Out:
#          name     parent       swap
# 0        head        NaN        NaN
# 1        eyeL       head       eyeR
# 2        eyeR       head       eyeL
# 3        neck       head        NaN
# 4      thorax       neck        NaN
# 5     abdomen     thorax        NaN
# 6   forelegR1        NaN  forelegL1
# 7   forelegR2  forelegR1  forelegL2
# 8   forelegR3  forelegR2  forelegL3
# 9   forelegR4  forelegR3  forelegL4
# 10   midlegR1        NaN   midlegL1
# 11   midlegR2   midlegR1   midlegL2
# 12   midlegR3   midlegR2   midlegL2
# 13   midlegR4   midlegR3   midlegL4
# 14  hindlegR1        NaN  hindlegL1
# 15  hindlegR2  hindlegR1  hindlegL2
# 16  hindlegR3  hindlegR2  hindlegL3
# 17  hindlegR4  hindlegR3  hindlegL4
# 18  forelegL1        NaN  forelegR1
# 19  forelegL2  forelegL1  forelegR2
# 20  forelegL3  forelegL2  forelegR3
# 21  forelegL4  forelegL3  forelegR4
# 22   midlegL1        NaN   midlegR1
# 23   midlegL2   midlegL1   midlegR2
# 24   midlegL3   midlegL2   midlegR3
# 25   midlegL4   midlegL3   midlegR4
# 26  hindlegL1        NaN  hindlegR1
# 27  hindlegL2  hindlegL1  hindlegR2
# 28  hindlegL3  hindlegL2  hindlegR3
# 29  hindlegL4  hindlegL3  hindlegR4
# 30      wingL       neck      wingR
# 31      wingR       neck      wingL

# %% [markdown]
# # Initialize a new data set for annotations
#
# You can use any method for sampling images to create a numpy array with the shape (n_images, height, width, channels) and then initialize an annotation set. Check the doc string for more details:

# %%
initialize_dataset?

# %%
initialize_dataset(
    images=kmeans_sampled_frames,
    datapath=HOME + '/deepposekit-data/datasets/fly/example_annotation_set.h5',
    skeleton=HOME + '/deepposekit-data/datasets/fly/skeleton.csv',
    # overwrite=True # This overwrites the existing datapath
)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-11-903a2a26f694> in <module>
# ----> 1 initialize_dataset(
#       2     images=kmeans_sampled_frames,
#       3     datapath=HOME + '/deepposekit-data/datasets/fly/example_annotation_set.h5',
#       4     skeleton=HOME + '/deepposekit-data/datasets/fly/skeleton.csv',
#       5     # overwrite=True # This overwrites the existing datapath
#
# ~\anaconda3\lib\site-packages\deepposekit\io\utils.py in initialize_dataset(datapath, images, skeleton, keypoints, dataset, overwrite)
#     105     """
#     106     if os.path.exists(datapath) and overwrite is False:
# --> 107         raise OSError(
#     108             "Annotation set {} already exists. Delete the file or set `overwrite=True`.".format(
#     109                 datapath
#
# OSError: Annotation set C:\Users\exley/deepposekit-data/datasets/fly/example_annotation_set.h5 already exists. Delete the file or set `overwrite=True`.

# %% [markdown]
# # Create a data generator
# This creates a `DataGenerator` for loading annotated data. Indexing the generator returns an image-keypoints pair, which you can then visualize. Right now all the keypoints are set to zero, because they haven't been annotated.
#
# You can also look at the doc string for more explanation:

# %%
DataGenerator?

# %%
data_generator = DataGenerator(HOME + '/deepposekit-data/datasets/fly/example_annotation_set.h5', mode="full")

image, keypoints = data_generator[0]

plt.figure(figsize=(5,5))
image = image[0] if image.shape[-1] is 3 else image[0, ..., 0]
cmap = None if image.shape[-1] is 3 else 'gray'
plt.imshow(image, cmap=cmap, interpolation='none')
for idx, jdx in enumerate(data_generator.graph):
    if jdx > -1:
        plt.plot(
            [keypoints[0, idx, 0], keypoints[0, jdx, 0]],
            [keypoints[0, idx, 1], keypoints[0, jdx, 1]],
            'r-'
        )
plt.scatter(keypoints[0, :, 0], keypoints[0, :, 1], c=np.arange(data_generator.keypoints_shape[0]), s=50, cmap=plt.cm.hsv, zorder=3)

plt.show()
